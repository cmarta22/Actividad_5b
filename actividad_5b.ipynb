# %% [markdown]
# ingrsado dos numeros por teclado a y b si es mayor que b

# %%
num1=int(input("ingrese el numero 1"))
num2=int(input("ingrese el numero 2"))
if num1>num2:
    print("hola politecnico malvinas")

# %% [markdown]
# ingrese dos numeros por teclado a y b si a es igual a b imprimir si a es mayor que bimprimir 2 sino imprimir 3

# %%
num1=int(input("ingrese numero 1:"))
num2=int(input("ingrese numero 2:"))
if num1==num2:
    print("los numeros son iguales")
else:
    print("los numeros son diferentes")
# Out:
# los numeros son diferentes

# %% [markdown]
# ingrese dos numeros por teclado a y b . si a es igual b imprimir 1 si es mayor que b imprimir 2 sino imprimir 3

# %%
num1=int(input("ingrese un numero 1"))
num2=int(input("ingrese un numero 2"))
if num1==num2:
    print(1)
elif num1>num2:
    print(2)
else:
    print(3)
# Out:
# 3

# %% [markdown]
# ingrese 4 cuatro numeros por teclado a,b,c y d . si a es igual b y c es igual  a d imprimir hola politecnico malvinas

# %%
num1=int(input("ingrese el numero1"))
num2=int(input("ingrese el numero2"))
num3=int(input("ingrese el numero 3"))
num4=int(input("ingrese el numero 4"))
if (num1==num2 and num3==num4):
    print("hola politecnico malvinas")

# %% [markdown]
# ingrese 4 numeros por teclado a,b,c,y d . si a es igual b o c es igual a d imprimir hola politecnico malvinas argentinas

# %%
num1=int(input("ingrese un numero 1"))
num2=int(input("ingrese un numero 2"))
num3=int(input("ingrese un numero 3"))
num4=int(input("ingrese un numero 4"))
if (num1==num2 or num3==num4):
    print("hola politecnico malvinas argentinas")

# %% [markdown]
# ingresar la edad de una persona por teclado mostrar por pantalla si es mayor o menor de edad

# %%
edad=int(input("ingrese su edad:"))
if edad>=18:
    print(" ud es mayor de edad")
else:
    print("ud es menor de edad")

# %% [markdown]
# ingresar un numero por teclado y mostrar por pantalla si es par o impar

# %%
num1=int(input("ingrese un numero "))
if num1%2==0:
    print("el numero es par")
else:
    print("el numero es impar")
# Out:
# el numero es par

# %% [markdown]
# ingrese por teclado 3 numeros y mostrar por pantalla el mayor de los 3

# %%
num1=int(input("ingrese el primer numero"))
num2=int(input("ingrese el segundo numero"))
num3=int(input("ingrese el tercer numero"))
if num1>num2 and num1>num3:
    mayor=num1
elif num2>num1 and num2>num3:
    mayor=num2
else:
    mayor=num3
    print("el mayor de los tres numeros es:",mayor)

# %% [markdown]
# ingrese por teclado un nombre , si la varieble nombre es nula mostrar por pantalla bienvenido + nombre sino mostrar bienvenido anonimo

# %%
nombre=(input("ingrese su nombre"))
if nombre!="":
    print("bienvenido",nombre)
else:
    print("bienvenido anonimo")
# Out:
# bienvenido maty
